# %% [markdown]
# # Install packages

# %%
# !pip install pandas matplotlib seaborn scipy windrose
# Out:
# Requirement already satisfied: pandas in c:\users\darkles\10academy\10academy-kifiya\env\lib\site-packages (2.2.3)
# Requirement already satisfied: matplotlib in c:\users\darkles\10academy\10academy-kifiya\env\lib\site-packages (3.9.3)
# Requirement already satisfied: seaborn in c:\users\darkles\10academy\10academy-kifiya\env\lib\site-packages (0.13.2)
# Requirement already satisfied: scipy in c:\users\darkles\10academy\10academy-kifiya\env\lib\site-packages (1.14.1)
# Requirement already satisfied: windrose in c:\users\darkles\10academy\10academy-kifiya\env\lib\site-packages (1.9.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\darkles\10academy\10academy-kifiya\env\lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\darkles\10academy\10academy-kifiya\env\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\darkles\10academy\10academy-kifiya\env\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\darkles\10academy\10academy-kifiya\env\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\darkles\10academy\10academy-kifiya\env\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\darkles\10academy\10academy-kifiya\env\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\darkles\10academy\10academy-kifiya\env\lib\site-packages (from matplotlib) (4.55.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\darkles\10academy\10academy-kifiya\env\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\darkles\10academy\10academy-kifiya\env\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\darkles\10academy\10academy-kifiya\env\lib\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\darkles\10academy\10academy-kifiya\env\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\darkles\10academy\10academy-kifiya\env\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip freeze > ../requirements.txt

# %% [markdown]
# # Importing libraries

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore
from windrose import WindroseAxes

# %% [markdown]
# Extract datasets from the data.zip

# %%
# import sys
# sys.path.append('..')

# from app.utils import extract_datasets

# # data_folder = "/content/drive/MyDrive/data/"
data_folder = r"../"
# data_path = os.path.join(data_folder, "data.zip")
# extract_datasets(data_path, data_folder)

# %% [markdown]
# # Load dataset sierraleone-bumbuna.csv and make initial analysis

# %%
data_folder = os.path.join(data_folder, "data")
df = pd.read_csv(os.path.join(data_folder, "sierraleone-bumbuna.csv"))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525600 entries, 0 to 525599
# Data columns (total 19 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Timestamp      525600 non-null  object
#  1   GHI            525600 non-null  float64
#  2   DNI            525600 non-null  float64
#  3   DHI            525600 non-null  float64
#  4   ModA           525600 non-null  float64
#  5   ModB           525600 non-null  float64
#  6   Tamb           525600 non-null  float64
#  7   RH             525600 non-null  float64
#  8   WS             525600 non-null  float64
#  9   WSgust         525600 non-null  float64
#  10  WSstdev        525600 non-null  float64
#  11  WD             525600 non-null  float64
#  12  WDstdev        525600 non-null  float64
#  13  BP             525600 non-null  int64
#  14  Cleaning       525600 non-null  int64
#  15  Precipitation  525600 non-null  float64
#  16  TModA          525600 non-null  float64
#  17  TModB          525600 non-null  float64
#  18  Comments       0 non-null       float64
# dtypes: float64(16), int64(2), object(1)
# memory usage: 76.2+ MB

# %%
df.columns
# Out:
# Index(['Timestamp', 'GHI', 'DNI', 'DHI', 'ModA', 'ModB', 'Tamb', 'RH', 'WS',
#        'WSgust', 'WSstdev', 'WD', 'WDstdev', 'BP', 'Cleaning', 'Precipitation',
#        'TModA', 'TModB', 'Comments'],
#       dtype='object')

# %%
df.describe()
# Out:
#                  GHI            DNI            DHI           ModA  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      201.957515     116.376337     113.720571     206.643095
# std       298.495150     218.652659     158.946032     300.896893
# min       -19.500000      -7.800000     -17.900000       0.000000
# 25%        -2.800000      -0.300000      -3.800000       0.000000
# 50%         0.300000      -0.100000      -0.100000       3.600000
# 75%       362.400000     107.000000     224.700000     359.500000
# max      1499.000000     946.000000     892.000000    1507.000000
#
#                 ModB           Tamb             RH             WS  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      198.114691      26.319394      79.448857       1.146113
# std       288.889073       4.398605      20.520775       1.239248
# min         0.000000      12.300000       9.900000       0.000000
# 25%         0.000000      23.100000      68.700000       0.000000
# 50%         3.400000      25.300000      85.400000       0.800000
# 75%       345.400000      29.400000      96.700000       2.000000
# max      1473.000000      39.900000     100.000000      19.200000
#
#               WSgust        WSstdev             WD        WDstdev  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean        1.691606       0.363823     133.044668       7.172220
# std         1.617053       0.295000     114.284792       7.535093
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         1.600000       0.400000     161.500000       6.200000
# 75%         2.600000       0.600000     234.100000      12.000000
# max        23.900000       4.100000     360.000000      98.400000
#
#                   BP       Cleaning  Precipitation          TModA  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      999.876469       0.000967       0.004806      32.504263
# std         2.104419       0.031074       0.047556      12.434899
# min       993.000000       0.000000       0.000000      10.700000
# 25%       999.000000       0.000000       0.000000      23.500000
# 50%      1000.000000       0.000000       0.000000      26.600000
# 75%      1001.000000       0.000000       0.000000      40.900000
# max      1006.000000       1.000000       2.400000      72.800000
#
#                TModB  Comments
# count  525600.000000       0.0
# mean       32.593091       NaN
# std        12.009161       NaN
# min        11.100000       NaN
# 25%        23.800000       NaN
# 50%        26.900000       NaN
# 75%        41.300000       NaN
# max        70.400000       NaN

# %%
# Check for missing values
df.isnull().sum()
# Out:
# Timestamp             0
# GHI                   0
# DNI                   0
# DHI                   0
# ModA                  0
# ModB                  0
# Tamb                  0
# RH                    0
# WS                    0
# WSgust                0
# WSstdev               0
# WD                    0
# WDstdev               0
# BP                    0
# Cleaning              0
# Precipitation         0
# TModA                 0
# TModB                 0
# Comments         525600
# dtype: int64

# %%
# Check for duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Statistics summary

# %%
# Summary statistics for numeric columns
df[['GHI', 'DNI', 'DHI', 'Tamb']].describe()
# Out:
#                  GHI            DNI            DHI           Tamb
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      201.957515     116.376337     113.720571      26.319394
# std       298.495150     218.652659     158.946032       4.398605
# min       -19.500000      -7.800000     -17.900000      12.300000
# 25%        -2.800000      -0.300000      -3.800000      23.100000
# 50%         0.300000      -0.100000      -0.100000      25.300000
# 75%       362.400000     107.000000     224.700000      29.400000
# max      1499.000000     946.000000     892.000000      39.900000

# %%
# Median of GHI
df['GHI'].median()
# Out:
# np.float64(0.3)

# %%
# Median of DNI
df['DNI'].median()
# Out:
# np.float64(-0.1)

# %%
# Median of DHI
df['DHI'].median()
# Out:
# np.float64(-0.1)

# %%
# Median of Tamb
df['Tamb'].median()
# Out:
# np.float64(25.3)

# %% [markdown]
# Ploting GHI, DNI and DHI

# %%
# Plotting time series trends for Benin_malanville dataset for the numeric columns
df['Timestamp'] = pd.to_datetime(df['Timestamp'])
df.set_index('Timestamp', inplace=True)
df[['GHI', 'DNI', 'DHI', 'Tamb']].plot(figsize=(10, 5), title='Solar Irradiance and Temperature Over Time for Benin_malanville')
plt.show()

# %%
df[['GHI', 'DNI', 'DHI', 'Tamb']].hist(bins=30, figsize=(10, 8))
plt.suptitle('Histograms for Benin_malanville Solar data')
plt.show()

# %% [markdown]
# Check for potential outliers

# %%
zscores = df[['GHI', 'DNI', 'DHI']].apply(zscore)
# zscores = df[['GHI', 'DNI', 'DHI', 'Tamb']].apply(zscore)
# zscores = df.apply(zscore)
zscores
# Out:
#                           GHI       DNI       DHI
# Timestamp
# 2021-10-30 00:01:00 -0.678931 -0.532701 -0.720500
# 2021-10-30 00:02:00 -0.678931 -0.532701 -0.720500
# 2021-10-30 00:03:00 -0.678931 -0.532701 -0.720500
# 2021-10-30 00:04:00 -0.678931 -0.532243 -0.720500
# 2021-10-30 00:05:00 -0.678931 -0.532701 -0.720500
# ...                       ...       ...       ...
# 2022-10-29 23:56:00 -0.681946 -0.532701 -0.733712
# 2022-10-29 23:57:00 -0.682281 -0.532701 -0.734342
# 2022-10-29 23:58:00 -0.682281 -0.532701 -0.734971
# 2022-10-29 23:59:00 -0.682281 -0.533158 -0.736229
# 2022-10-30 00:00:00 -0.682281 -0.532701 -0.736858
#
# [525600 rows x 3 columns]

# %%
# outliers = (zscores > 3).any(axis=1)
outliers = (zscores.abs() > 3).any(axis=1)
outliers.sum()
# Out:
# np.int64(11548)

# %%
sns.boxplot(data=df[['GHI', 'DNI', 'DHI']])
plt.title('Boxplot of GHI, DNI, and DHI')
plt.show()

# %%
plt.figure(figsize=(15, 10))
sns.boxplot(data=df)
# Out:
# <Axes: >

# %% [markdown]
# Data Cleaning

# %%
# missing data
df.fillna(method='ffill', inplace=True) # forward fill
# df.fillna(method='bfill', inplace=True) # backward fill
# Out:
# C:\Users\Darkles\AppData\Local\Temp\ipykernel_9036\2401482676.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True) # forward fill

# %%
# drop duplicates
df.drop_duplicates(inplace=True)

# %% [markdown]
# Visializations and Correlation Analysis

# %%
correlation = df.corr()
correlation
# Out:
#                     GHI       DNI       DHI      ModA      ModB      Tamb  \
# GHI            1.000000  0.867930  0.863752  0.994981  0.994536  0.636462
# DNI            0.867930  1.000000  0.531411  0.875382  0.873853  0.574224
# DHI            0.863752  0.531411  1.000000  0.847930  0.848488  0.562221
# ModA           0.994981  0.875382  0.847930  1.000000  0.999114  0.632362
# ModB           0.994536  0.873853  0.848488  0.999114  1.000000  0.628886
# Tamb           0.636462  0.574224  0.562221  0.632362  0.628886  1.000000
# RH            -0.538373 -0.543391 -0.420181 -0.556695 -0.549673 -0.789255
# WS             0.359166  0.301604  0.333539  0.354118  0.352445  0.530637
# WSgust         0.399049  0.331984  0.371769  0.394075  0.392338  0.548392
# WSstdev        0.398856  0.327648  0.374547  0.395892  0.394518  0.472358
# WD             0.390845  0.304552  0.388911  0.380392  0.380185  0.480121
# WDstdev        0.533299  0.464238  0.469965  0.535554  0.533385  0.564234
# BP            -0.131493 -0.209031 -0.048909 -0.135624 -0.130385 -0.510249
# Cleaning       0.008117  0.002169  0.017516  0.006278  0.007918 -0.011999
# Precipitation -0.064772 -0.055228 -0.064364 -0.064829 -0.064662 -0.065580
# TModA          0.922058  0.814842  0.805393  0.927316  0.925702  0.829386
# TModB          0.911062  0.806502  0.804426  0.911780  0.910481  0.853007
# Comments            NaN       NaN       NaN       NaN       NaN       NaN
#
#                      RH        WS    WSgust   WSstdev        WD   WDstdev  \
# GHI           -0.538373  0.359166  0.399049  0.398856  0.390845  0.533299
# DNI           -0.543391  0.301604  0.331984  0.327648  0.304552  0.464238
# DHI           -0.420181  0.333539  0.371769  0.374547  0.388911  0.469965
# ModA          -0.556695  0.354118  0.394075  0.395892  0.380392  0.535554
# ModB          -0.549673  0.352445  0.392338  0.394518  0.380185  0.533385
# Tamb          -0.789255  0.530637  0.548392  0.472358  0.480121  0.564234
# RH             1.000000 -0.456895 -0.467883 -0.395608 -0.326466 -0.496062
# WS            -0.456895  1.000000  0.973372  0.721450  0.551855  0.633132
# WSgust        -0.467883  0.973372  1.000000  0.834529  0.612784  0.690607
# WSstdev       -0.395608  0.721450  0.834529  1.000000  0.679596  0.715051
# WD            -0.326466  0.551855  0.612784  0.679596  1.000000  0.578505
# WDstdev       -0.496062  0.633132  0.690607  0.715051  0.578505  1.000000
# BP             0.569804 -0.282799 -0.266130 -0.176564 -0.166884 -0.219926
# Cleaning       0.011557 -0.014140 -0.012790 -0.007934 -0.009839 -0.007539
# Precipitation  0.086139  0.124502  0.129254  0.097686  0.019242  0.038061
# TModA         -0.682245  0.424285  0.462408  0.449360  0.446674  0.590529
# TModB         -0.692811  0.443836  0.479276  0.456136  0.470349  0.593467
# Comments            NaN       NaN       NaN       NaN       NaN       NaN
#
#                      BP  Cleaning  Precipitation     TModA     TModB  Comments
# GHI           -0.131493  0.008117      -0.064772  0.922058  0.911062       NaN
# DNI           -0.209031  0.002169      -0.055228  0.814842  0.806502       NaN
# DHI           -0.048909  0.017516      -0.064364  0.805393  0.804426       NaN
# ModA          -0.135624  0.006278      -0.064829  0.927316  0.911780       NaN
# ModB          -0.130385  0.007918      -0.064662  0.925702  0.910481       NaN
# Tamb          -0.510249 -0.011999      -0.065580  0.829386  0.853007       NaN
# RH             0.569804  0.011557       0.086139 -0.682245 -0.692811       NaN
# WS            -0.282799 -0.014140       0.124502  0.424285  0.443836       NaN
# WSgust        -0.266130 -0.012790       0.129254  0.462408  0.479276       NaN
# WSstdev       -0.176564 -0.007934       0.097686  0.449360  0.456136       NaN
# WD            -0.166884 -0.009839       0.019242  0.446674  0.470349       NaN
# WDstdev       -0.219926 -0.007539       0.038061  0.590529  0.593467       NaN
# BP             1.000000  0.018707       0.062088 -0.268840 -0.303134       NaN
# Cleaning       0.018707  1.000000      -0.002840 -0.000127  0.001618       NaN
# Precipitation  0.062088 -0.002840       1.000000 -0.070468 -0.071611       NaN
# TModA         -0.268840 -0.000127      -0.070468  1.000000  0.993113       NaN
# TModB         -0.303134  0.001618      -0.071611  0.993113  1.000000       NaN
# Comments            NaN       NaN            NaN       NaN       NaN       NaN

# %%
plt.figure(figsize=(15, 10))
sns.heatmap(correlation, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
sns.scatterplot(x='GHI', y='Tamb', data=df, hue='Cleaning', style='Cleaning')
plt.title('GHI vs. Ambient Temperature')
plt.show()

# %% [markdown]
# Impact of the cleaning analysis done

# %%
# Group data by Cleaning status
cleaned_data = df[df['Cleaning'] == 1]
not_cleaned_data = df[df['Cleaning'] == 0]

# Calculate average readings
avg_cleaned = cleaned_data[['ModA', 'ModB']].mean()
avg_not_cleaned = not_cleaned_data[['ModA', 'ModB']].mean()

# Bar chart comparison
avg_df = pd.DataFrame({'Cleaned': avg_cleaned, 'Not Cleaned': avg_not_cleaned}).T
avg_df.plot(kind='bar', figsize=(8, 5))
plt.title('Average Sensor Readings (Cleaned vs. Not Cleaned)')
plt.ylabel('Average Value (W/m²)')
plt.xticks(rotation=0)
plt.show()

# %%
# check trends over time
df.groupby('Cleaning')[['ModA', 'ModB']].mean().plot(kind='line', figsize=(10, 5))
plt.title('Sensor Readings Over Time (By Cleaning Status)')
plt.ylabel('Value (W/m²)')
plt.show()

# %% [markdown]
# # Advanced Analysis with Correlation and Pair Plots

# %% [markdown]
# Wind analysis

# %%
# Create a wind rose visualization to analyze speed and direction
ax = WindroseAxes.from_ax()
ax.bar(df['WD'], df['WS'], normed=True, opening=0.8, edgecolor='black')
ax.set_title('Wind Rose: Speed vs. Direction')
ax.set_legend()
plt.show()

# %%
# Analyze wind direction variability
sns.histplot(df['WD'], kde=True, bins=36)
plt.title('Wind Direction Distribution')
plt.xlabel('Wind Direction (°N)')
plt.show()

# %% [markdown]
# Temperature and Humidity Analysis

# %%
# Analyze the relationship between temperature and relative humidity
sns.scatterplot(x='Tamb', y='RH', data=df, alpha=0.7)
plt.title('Temperature vs. Relative Humidity')
plt.xlabel('Ambient Temperature (°C)')
plt.ylabel('Relative Humidity (%)')
plt.show()

# %%
# Investigate temperature variations across modules
df[['TModA', 'TModB', 'Tamb']].plot(figsize=(10, 5))
plt.title('Temperature Trends Across Modules')
plt.ylabel('Temperature (°C)')
plt.show()

# %%
# Generate a pair plot
sns.pairplot(df[['GHI', 'DNI', 'DHI', 'Tamb', 'RH', 'WS']])
plt.suptitle('Pair Plot of Key Variables', y=1.02)
plt.show()

# %%
# Identify strong correlations between GHI, DNI, DHI Tamb, RH and WS
df[['GHI', 'DNI', 'DHI', 'Tamb', 'RH', 'WS']].corr()
# Out:
#            GHI       DNI       DHI      Tamb        RH        WS
# GHI   1.000000  0.867930  0.863752  0.636462 -0.538373  0.359166
# DNI   0.867930  1.000000  0.531411  0.574224 -0.543391  0.301604
# DHI   0.863752  0.531411  1.000000  0.562221 -0.420181  0.333539
# Tamb  0.636462  0.574224  0.562221  1.000000 -0.789255  0.530637
# RH   -0.538373 -0.543391 -0.420181 -0.789255  1.000000 -0.456895
# WS    0.359166  0.301604  0.333539  0.530637 -0.456895  1.000000

# %% [markdown]
#  Z-Score and Outlier Detection for GHI, DNI and DHI

# %%
# Flag extreme outliers using Z-scores
z_scores = df[['GHI', 'DNI', 'DHI']].apply(zscore)
outlier_df = df[z_scores.abs() > 3].dropna()
outlier_df # Number of outliers detected
# Out:
# Empty DataFrame
# Columns: [GHI, DNI, DHI, ModA, ModB, Tamb, RH, WS, WSgust, WSstdev, WD, WDstdev, BP, Cleaning, Precipitation, TModA, TModB, Comments]
# Index: []

# %%
# Visualize outliers
sns.boxplot(data=df[['GHI', 'DNI', 'DHI']])
plt.title('Boxplot of Solar Radiation Components')
plt.show()
